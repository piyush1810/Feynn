# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as poi
import seaborn as sns
from kmodes.kprototypes import KPrototypes

# %%
df=pd.read_csv("Car.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   choice  college  hsg2  coml5   type1   type2   type3    type4
# 0           1  choice1        0     0      0     van  regcar     van  stwagon  \
# 1           2  choice2        1     1      1  regcar     van  regcar  stwagon
# 2           3  choice5        0     1      0  regcar   truck  regcar      van
# 3           4  choice5        0     0      1  regcar   truck  regcar      van
# 4           5  choice5        0     1      0  regcar   truck  regcar      van
#
#     type5  ... pollution3 pollution4 pollution5 pollution6 size1 size2 size3
# 0     van  ...       0.25       0.25       0.50       0.50     3     3     2  \
# 1  regcar  ...       0.40       0.40       0.25       0.25     3     3     3
# 2  regcar  ...       0.40       0.40       0.75       0.75     2     2     3
# 3  regcar  ...       0.25       0.25       0.60       0.60     2     2     3
# 4  regcar  ...       0.40       0.40       0.75       0.75     1     1     2
#
#    size4  size5  size6
# ...

# %%
df.shape
# Out:
# (300, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 41 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  300 non-null    int64
#  1   choice      300 non-null    object
#  2   college     300 non-null    int64
#  3   hsg2        300 non-null    int64
#  4   coml5       300 non-null    int64
#  5   type1       300 non-null    object
#  6   type2       300 non-null    object
#  7   type3       300 non-null    object
#  8   type4       300 non-null    object
#  9   type5       300 non-null    object
#  10  type6       300 non-null    object
#  11  fuel1       300 non-null    object
#  12  fuel2       300 non-null    object
#  13  fuel3       300 non-null    object
#  14  fuel4       300 non-null    object
#  15  fuel5       300 non-null    object
#  16  fuel6       300 non-null    object
#  17  price1      300 non-null    float64
#  18  price2      300 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# choice        0
# college       0
# hsg2          0
# coml5         0
# type1         0
# type2         0
# type3         0
# type4         0
# type5         0
# type6         0
# fuel1         0
# fuel2         0
# fuel3         0
# fuel4         0
# fuel5         0
# fuel6         0
# price1        0
# price2        0
# price3        0
# price4        0
# price5        0
# price6        0
# speed1        0
# speed2        0
# speed3        0
# speed4        0
# speed5        0
# speed6        0
# pollution1    0
# pollution2    0
# pollution3    0
# pollution4    0
# pollution5    0
# pollution6    0
# size1         0
# size2         0
# size3         0
# size4         0
# size5         0
# size6         0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0     college        hsg2       coml5      price1      price2
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000  \
# mean   150.500000    0.640000    0.293333    0.420000    4.377107    4.377107
# std     86.746758    0.480802    0.456051    0.494383    1.934018    1.934018
# min      1.000000    0.000000    0.000000    0.000000    0.963541    0.963541
# 25%     75.750000    0.000000    0.000000    0.000000    3.303749    3.303749
# 50%    150.500000    1.000000    0.000000    0.000000    4.138683    4.138683
# 75%    225.250000    1.000000    1.000000    1.000000    5.242332    5.242332
# max    300.000000    1.000000    1.000000    1.000000   17.370563   17.370563
#
#            price3      price4      price5      price6  ...  pollution3
# count  300.000000  300.000000  300.000000  300.000000  ...  300.000000  \
# mean     4.210331    4.210331    4.130504    4.130504  ...    0.405500
# ...

# %%
df['type1'].value_counts(normalize=True)
# Out:
# type1
# regcar      0.660000
# truck       0.140000
# van         0.096667
# sportuv     0.063333
# sportcar    0.033333
# stwagon     0.006667
# Name: proportion, dtype: float64

# %%
df['type1'].value_counts(normalize=True).plot(kind='pie',autopct='%1.0f%%',legend=True,title='Preferred Car Type')
# Out:
# <Axes: title={'center': 'Preferred Car Type'}, ylabel='proportion'>

# %%
df['fuel1'].value_counts(normalize=True)
# Out:
# fuel1
# methanol    0.743333
# cng         0.256667
# Name: proportion, dtype: float64

# %%
df['fuel1'].value_counts(normalize=True).plot(kind='pie',autopct='%1.0f%%',legend=True,title='Fuel Used')
# Out:
# <Axes: title={'center': 'Fuel Used'}, ylabel='proportion'>

# %%
df['size1'].value_counts(normalize=True)
# Out:
# size1
# 3    0.553333
# 2    0.320000
# 1    0.100000
# 0    0.026667
# Name: proportion, dtype: float64

# %%
df['size1'].value_counts(normalize=True).plot(kind='pie',autopct='%1.0f%%',legend=True,title='Number of dependents')
# Out:
# <Axes: title={'center': 'Number of dependents'}, ylabel='proportion'>

# %%
sns.countplot(x='college',hue='type1',data=df)
plt.show()

# %%
df.plot(kind='scatter',x='price1',y='speed1')
# Out:
# <Axes: xlabel='price1', ylabel='speed1'>

# %%
sns.pairplot(df)
